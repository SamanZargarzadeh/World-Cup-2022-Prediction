# %% [markdown]
# # Data Anlysis

# %%
import pandas as pd
import numpy as np

# %%
Dataset=pd.read_csv(r'/Users/macbook/Desktop/Data_for_analysis.csv')
Dataset.head()
# Out:
#    Unnamed: 0  index  year                hname          aname  hgoals  \
# 0           0     22  2016        United States         Mexico       1
# 1           1     23  2016           Costa Rica  United States       4
# 2           2     25  2017  Trinidad and Tobago         Panama       1
# 3           3     26  2017               Mexico     Costa Rica       2
# 4           4     27  2017  Trinidad and Tobago         Mexico       0
#
#    agoals  hPossesion  aPossesion  hshotsOnTarget  ...  aavg_shotsOnTarget  \
# 0       2          42          58               7  ...                5.50
# 1       0          48          52               9  ...                6.75
# 2       0          48          52               5  ...                3.00
# 3       0          55          45               4  ...                6.00
# 4       1          48          52               1  ...                4.50
#
#    aavg_shots  aavg_yellowCards  aavg_redCards  aavg_fouls  aavg_rating  \
# ...

# %%
list(Dataset.columns)
# Out:
# ['Unnamed: 0',
#  'index',
#  'year',
#  'hname',
#  'aname',
#  'hgoals',
#  'agoals',
#  'hPossesion',
#  'aPossesion',
#  'hshotsOnTarget',
#  'ashotsOnTarget',
#  'hshots',
#  'ashots',
#  'hyellowCards',
#  'ayellowCards',
#  'hredCards',
#  'aredCards',
#  'hfouls',
#  'afouls',
#  'h_rating',
#  'h_eoy_rank',
#  'h_boy_rank',
#  'a_rating',
#  'a_eoy_rank',
#  'a_boy_rank',
#  'havg_goals',
#  'havg_Possesion',
#  'havg_shotsOnTarget',
#  'havg_shots',
#  'havg_yellowCards',
#  'havg_redCards',
#  'havg_fouls',
#  'havg_rating',
#  'havg_eoy_rank',
#  'havg_boy_rank',
#  'home_no_games',
#  'aavg_goals',
#  'aavg_Possesion',
#  'aavg_shotsOnTarget',
#  'aavg_shots',
#  'aavg_yellowCards',
#  'aavg_redCards',
#  'aavg_fouls',
#  'aavg_rating',
#  'aavg_eoy_rank',
#  'aavg_boy_rank',
#  'away_no_games',
#  'results']

# %% [markdown]
# # Correlation

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 10))
cmap = sns.color_palette("icefire", as_cmap=True)

sns.heatmap(Dataset[['h_rating',
 'h_eoy_rank',
 'h_boy_rank',
 'a_rating',
 'a_eoy_rank',
 'a_boy_rank',
 'havg_goals',
 'havg_Possesion',
 'havg_shotsOnTarget',
 'havg_shots',
 'havg_yellowCards',
 'havg_redCards',
 'havg_fouls',
 'havg_rating',
 'havg_eoy_rank',
 'havg_boy_rank',
 'home_no_games',
 'aavg_goals',
 'aavg_Possesion',
 'aavg_shotsOnTarget',
 'aavg_shots',
 'aavg_yellowCards',
 'aavg_redCards',
 'aavg_fouls',
 'aavg_rating',
 'aavg_eoy_rank',
 'aavg_boy_rank',
 'away_no_games']].corr() , cmap=cmap)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 10))
cmap = sns.color_palette("icefire", as_cmap=True)

sns.heatmap(Dataset[['h_rating',
 'h_eoy_rank',
 'h_boy_rank',
 'a_rating',
 'a_eoy_rank',
 'a_boy_rank']].corr() , cmap=cmap)
plt.show()

# %% [markdown]
# # Box plot

# %%
data_difs = Dataset[['h_rating',
 'h_eoy_rank',
 'h_boy_rank',
 'a_rating',
 'a_eoy_rank',
 'a_boy_rank']]
scaled = (data_difs - data_difs.mean()) / data_difs.std()
scaled["results"] = Dataset["results"]
violin = pd.melt(scaled,id_vars="results", var_name="features", value_name="value")

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x="features", y="value", hue="results", data=violin , color='c')
plt.xticks(rotation=90)
plt.show()

# %%
data_difs = Dataset[['h_rating',
 'h_eoy_rank',
 'h_boy_rank',
 'a_rating',
 'a_eoy_rank',
 'a_boy_rank',
 'havg_goals',
 'havg_Possesion',
 'havg_shotsOnTarget',
 'havg_shots',
 'havg_yellowCards',
 'havg_redCards',
 'havg_fouls',
 'havg_rating',
 'havg_eoy_rank',
 'havg_boy_rank',
 'home_no_games',
 'aavg_goals',
 'aavg_Possesion',
 'aavg_shotsOnTarget',
 'aavg_shots',
 'aavg_yellowCards',
 'aavg_redCards',
 'aavg_fouls',
 'aavg_rating',
 'aavg_eoy_rank',
 'aavg_boy_rank',
 'away_no_games']]
scaled = (data_difs - data_difs.mean()) / data_difs.std()
scaled["results"] = Dataset["results"]
violin = pd.melt(scaled,id_vars="results", var_name="features", value_name="value")

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x="features", y="value", hue="results", data=violin , color='c')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # This Year Teams

# %%
Teams=pd.read_csv(r'/Users/macbook/Desktop/32Teams.csv')
Teams.head()
# Out:
#         Name  Rating  End Ranking  Beginning Ranking  Avg Goals  \
# 0  Argentina    84.9            4                  3   1.538462
# 1  Australia    73.7           42                 37   1.250000
# 2    Belgium    83.9            2                  1   2.000000
# 3     Brazil    86.5            2                  1   2.076923
# 4   Cameroon    76.9           43                 37   1.000000
#
#    Avg Possesion  Avg shots on Target  Avg shots  Avg Yellow Cards  \
# 0      60.538462             6.230769  13.769231          1.692308
# 1      57.500000             6.750000  13.000000          1.500000
# 2      66.500000             5.500000  13.250000          2.250000
# 3      59.384615             6.538462  13.384615          2.000000
# 4      51.000000             4.000000   5.000000          2.000000
#
#    Avg Red Cards  Avg fouls  Avg Rating  Avg End Rank  Avg beginning Rank  \
# 0            0.0  12.923077   85.053846      8.307692            5.615385
# ...

# %%
list(Teams.columns)
# Out:
# ['Name',
#  'Rating',
#  'End Ranking',
#  'Beginning Ranking',
#  'Avg Goals',
#  'Avg Possesion',
#  'Avg shots on Target',
#  'Avg shots',
#  'Avg Yellow Cards',
#  'Avg Red Cards',
#  'Avg fouls',
#  'Avg Rating',
#  'Avg End Rank',
#  'Avg beginning Rank',
#  'Number of Games']

# %% [markdown]
# ### You can change the columns name and get the box plot you want

# %%
import matplotlib.pyplot as plt
import seaborn as sns


sns.boxplot(Teams['Avg Possesion'])


plt.show()
# Out:
# /Users/macbook/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### It kinda show how many of the shoots was on target and how many goals

# %%
violin = pd.melt(Teams[[
 'Avg Goals',
 'Avg shots on Target',
 'Avg shots']], var_name="features", value_name="value")

# %%
plt.figure(figsize=(10,10))
sns.violinplot(x="features", y="value", data=violin, split=True,  color='c')
plt.xticks(rotation=90)
plt.show()
